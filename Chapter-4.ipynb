# %% [markdown]
# ### Using loc and iloc

# %%
import pandas as pd 

college = pd.read_csv('D:/python/Pandas/PandasCookbook_Code/data/college.csv',index_col='INSTNM')
city = college['CITY']
city.loc['Enterprise State Community College']
# Out:
# 'Enterprise'

# %%
city.head(20)
# Out:
# 0             Normal
# 1         Birmingham
# 2         Montgomery
# 3         Huntsville
# 4         Montgomery
# 5         Tuscaloosa
# 6     Alexander City
# 7             Athens
# 8         Montgomery
# 9             Auburn
# 10        Birmingham
# 11       Phenix City
# 12             Selma
# 13        Montgomery
# 14        Enterprise
# 15       Bay Minette
# 16        Montgomery
# 17           Gadsden
# 18       Albertville
# 19            Dothan
# Name: CITY, dtype: object

# %%
college.head(60)
# Out:
#                                                               CITY STABBR  ...    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM                                                                     ...
# Alabama A & M University                                    Normal     AL  ...              30300               33888
# University of Alabama at Birmingham                     Birmingham     AL  ...              39700             21941.5
# Amridge University                                      Montgomery     AL  ...              40100               23370
# University of Alabama in Huntsville                     Huntsville     AL  ...              45500               24097
# Alabama State University                                Montgomery     AL  ...              26600             33118.5
# The University of Alabama                               Tuscaloosa     AL  ...              41900               23750
# ...

# %%
college.iloc[58]
# Out:
# CITY                             Daphne
# STABBR                               AL
# HBCU                                0.0
# MENONLY                             0.0
# WOMENONLY                           0.0
# RELAFFIL                              0
# SATVRMID                            NaN
# SATMTMID                            NaN
# DISTANCEONLY                        0.0
# UGDS                               90.0
# UGDS_WHITE                       0.4333
# UGDS_BLACK                       0.1222
# UGDS_HISP                        0.0667
# UGDS_ASIAN                       0.0222
# UGDS_AIAN                           0.0
# UGDS_NHPI                           0.0
# UGDS_2MOR                        0.0444
# UGDS_NRA                            0.0
# UGDS_UNKN                        0.3111
# PPTUG_EF                         0.8111
# CURROPER                              1
# PCTPELL                             0.4
# PCTFLOAN                         0.4632
# ...

# %%
college.iloc[10:20]
# Out:
#                                                         CITY STABBR  HBCU  ...  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM                                                                     ...
# Birmingham Southern College                       Birmingham     AL   0.0  ...   0.0152            44200               27000
# Chattahoochee Valley Community College           Phenix City     AL   0.0  ...   0.3876            26100                9000
# Concordia College Alabama                              Selma     AL   1.0  ...   0.2367            19900   PrivacySuppressed
# South University-Montgomery                       Montgomery     AL   0.0  ...   0.5726            28800               25167
# Enterprise State Community College                Enterprise     AL   0.0  ...   0.3399            24600                8273
# James H Faulkner State Community College         Bay Minette     AL   0.0  ...   0.2909            28700               11000
# ...

# %%
college.iloc[2:8,0:3]
# Out:
#                                                CITY STABBR  HBCU
# INSTNM
# Amridge University                       Montgomery     AL   0.0
# University of Alabama in Huntsville      Huntsville     AL   0.0
# Alabama State University                 Montgomery     AL   1.0
# The University of Alabama                Tuscaloosa     AL   0.0
# Central Alabama Community College    Alexander City     AL   0.0
# Athens State University                      Athens     AL   0.0

# %%
college.iloc[:,[2,4]]
# Out:
#                                                     HBCU  WOMENONLY
# INSTNM
# Alabama A & M University                             1.0        0.0
# University of Alabama at Birmingham                  0.0        0.0
# Amridge University                                   0.0        0.0
# University of Alabama in Huntsville                  0.0        0.0
# Alabama State University                             1.0        0.0
# ...                                                  ...        ...
# SAE Institute of Technology  San Francisco           NaN        NaN
# Rasmussen College - Overland Park                    NaN        NaN
# National Personal Training Institute of Cleveland    NaN        NaN
# Bay Area Medical Academy - San Jose Satellite L...   NaN        NaN
# Excel Learning Center-San Antonio South              NaN        NaN
#
# [7535 rows x 2 columns]

# %%
college.columns
# Out:
# Index(['CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
college.iloc[5]
# Out:
# CITY                  Tuscaloosa
# STABBR                        AL
# HBCU                         0.0
# MENONLY                      0.0
# WOMENONLY                    0.0
# RELAFFIL                       0
# SATVRMID                   555.0
# SATMTMID                   565.0
# DISTANCEONLY                 0.0
# UGDS                     29851.0
# UGDS_WHITE                0.7825
# UGDS_BLACK                0.1119
# UGDS_HISP                 0.0348
# UGDS_ASIAN                0.0106
# UGDS_AIAN                 0.0038
# UGDS_NHPI                 0.0009
# UGDS_2MOR                 0.0261
# UGDS_NRA                  0.0268
# UGDS_UNKN                 0.0026
# PPTUG_EF                  0.0844
# CURROPER                       1
# PCTPELL                    0.204
# PCTFLOAN                   0.401
# UG25ABV                   0.0853
# MD_EARN_WNE_P10            41900
# GRAD_DEBT_MDN_SUPP         23750
# Name: The University of Alabama, dtype: object

# %%
# %timeit college.iloc[:,[4,5]]
# Out:
# 433 µs ± 15.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
college['Alabama A & M University':'Alabama State University':2]
# Out:
#                                 CITY STABBR  HBCU  MENONLY  ...  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM                                                      ...
# Alabama A & M University      Normal     AL   1.0      0.0  ...    0.8284   0.1049            30300               33888
# Amridge University        Montgomery     AL   0.0      0.0  ...    0.7795   0.8540            40100               23370
# Alabama State University  Montgomery     AL   1.0      0.0  ...    0.7554   0.1270            26600             33118.5
#
# [3 rows x 26 columns]

# %%
college.sort_index(inplace=True)

# %%
college.loc['D':'E']
# Out:
#                                                     CITY STABBR  HBCU  ...  UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# INSTNM                                                                 ...
# D & L Academy of Hair Design                  Twin Falls     ID   0.0  ...   0.6000                NaN   PrivacySuppressed
# D A Dorsey Technical College                       Miami     FL   0.0  ...   0.3696                NaN   PrivacySuppressed
# D'Jay's School of Beauty Arts and Sciences   Baton Rouge     LA   0.0  ...   0.4286              15500                7327
# D'Mart Institute                            Barranquitas     PR   0.0  ...   0.3523              12900   PrivacySuppressed
# D'Youville College                               Buffalo     NY   0.0  ...   0.3099              48000               25500
# ...                                                  ...    ...   ...  ...      ...                ...                 ...
# ...
